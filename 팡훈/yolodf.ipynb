# %% [markdown]
# <a href="https://colab.research.google.com/github/kikiru328/Bone_Detection/blob/main/%ED%8C%A1%ED%9B%88/yolodf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import seaborn as sns
import os
# %matplotlib inline

# %%
carpal_path = '/content/drive/MyDrive/2차 프로젝트 원본 데이터/crop_img/female/CARPAL'
carpal = os.listdir(carpal_path) 

ip_path = '/content/drive/MyDrive/2차 프로젝트 원본 데이터/crop_img/female/IP'
ip = os.listdir(ip_path)

lpip_path = '/content/drive/MyDrive/2차 프로젝트 원본 데이터/crop_img/female/LPIP'
lpip = os.listdir(lpip_path)

mpip_path = '/content/drive/MyDrive/2차 프로젝트 원본 데이터/crop_img/female/MPIP'
mpip = os.listdir(mpip_path)

LMCP_path = '/content/drive/MyDrive/2차 프로젝트 원본 데이터/crop_img/female/LMCP'
lmcp = os.listdir(LMCP_path)

MMCP_path = '/content/drive/MyDrive/2차 프로젝트 원본 데이터/crop_img/female/MMCP'
mmcp = os.listdir(MMCP_path)

TMCP_path = '/content/drive/MyDrive/2차 프로젝트 원본 데이터/crop_img/female/TMCP'
tmcp = os.listdir(TMCP_path)

# %%
female = pd.DataFrame({'carpal':carpal,'lmcp':lmcp,'mmcp':mmcp,'tmcp':tmcp,'lpip':lpip,'mpip':mpip,'ip':ip})

# %%
female
# Out:
#            carpal          lmcp  ...          mpip            ip
# 0      1_F_cp.jpg    1_F_lm.jpg  ...    1_F_mp.jpg    1_F_ip.jpg
# 1      2_F_cp.jpg    2_F_lm.jpg  ...    2_F_mp.jpg    2_F_ip.jpg
# 2      3_F_cp.jpg    3_F_lm.jpg  ...    3_F_mp.jpg    3_F_ip.jpg
# 3      4_F_cp.jpg    4_F_lm.jpg  ...    4_F_mp.jpg    4_F_ip.jpg
# 4      5_F_cp.jpg    5_F_lm.jpg  ...    5_F_mp.jpg    5_F_ip.jpg
# ..            ...           ...  ...           ...           ...
# 566  568_F_cp.jpg  568_F_lm.jpg  ...  568_F_mp.jpg  568_F_ip.jpg
# 567  569_F_cp.jpg  569_F_lm.jpg  ...  569_F_mp.jpg  569_F_ip.jpg
# 568  570_F_cp.jpg  570_F_lm.jpg  ...  570_F_mp.jpg  570_F_ip.jpg
# 569  571_F_cp.jpg  571_F_lm.jpg  ...  571_F_mp.jpg  571_F_ip.jpg
# 570  572_F_cp.jpg  572_F_lm.jpg  ...  572_F_mp.jpg  572_F_ip.jpg
#
# [571 rows x 7 columns]

# %%
len(carpal)
# Out:
# 571

# %%
carpal_path = '/content/drive/MyDrive/2차 프로젝트 원본 데이터/crop_img/male/CARPAL'
carpal = os.listdir(carpal_path) 

ip_path = '/content/drive/MyDrive/2차 프로젝트 원본 데이터/crop_img/male/IP'
ip = os.listdir(ip_path)

lpip_path = '/content/drive/MyDrive/2차 프로젝트 원본 데이터/crop_img/male/LPIP'
lpip = os.listdir(lpip_path)

mpip_path = '/content/drive/MyDrive/2차 프로젝트 원본 데이터/crop_img/male/MPIP'
mpip = os.listdir(mpip_path)

LMCP_path = '/content/drive/MyDrive/2차 프로젝트 원본 데이터/crop_img/male/LMCP'
lmcp = os.listdir(LMCP_path)

MMCP_path = '/content/drive/MyDrive/2차 프로젝트 원본 데이터/crop_img/male/MMCP'
mmcp = os.listdir(MMCP_path)

TMCP_path = '/content/drive/MyDrive/2차 프로젝트 원본 데이터/crop_img/male/TMCP'
tmcp = os.listdir(TMCP_path)

# %%
male = pd.DataFrame({'carpal':carpal,'lmcp':lmcp,'mmcp':mmcp,'tmcp':tmcp,'lpip':lpip,'mpip':mpip,'ip':ip})

# %%
male
# Out:
#            carpal          lmcp  ...          mpip            ip
# 0      1_M_cp.jpg    1_M_lm.jpg  ...    1_M_mp.jpg    1_M_ip.jpg
# 1      2_M_cp.jpg    2_M_lm.jpg  ...    2_M_mp.jpg    2_M_ip.jpg
# 2      3_M_cp.jpg    3_M_lm.jpg  ...    3_M_mp.jpg    3_M_ip.jpg
# 3      4_M_cp.jpg    4_M_lm.jpg  ...    4_M_mp.jpg    4_M_ip.jpg
# 4      5_M_cp.jpg    5_M_lm.jpg  ...    5_M_mp.jpg    5_M_ip.jpg
# ..            ...           ...  ...           ...           ...
# 660  661_M_cp.jpg  661_M_lm.jpg  ...  661_M_mp.jpg  661_M_ip.jpg
# 661  662_M_cp.jpg  662_M_lm.jpg  ...  662_M_mp.jpg  662_M_ip.jpg
# 662  663_M_cp.jpg  663_M_lm.jpg  ...  663_M_mp.jpg  663_M_ip.jpg
# 663  664_M_cp.jpg  664_M_lm.jpg  ...  664_M_mp.jpg  664_M_ip.jpg
# 664  665_M_cp.jpg  665_M_lm.jpg  ...  665_M_mp.jpg  665_M_ip.jpg
#
# [665 rows x 7 columns]

# %%
x = pd.concat([female,male],axis=0)
x
# Out:
#            carpal          lmcp  ...          mpip            ip
# 0      1_F_cp.jpg    1_F_lm.jpg  ...    1_F_mp.jpg    1_F_ip.jpg
# 1      2_F_cp.jpg    2_F_lm.jpg  ...    2_F_mp.jpg    2_F_ip.jpg
# 2      3_F_cp.jpg    3_F_lm.jpg  ...    3_F_mp.jpg    3_F_ip.jpg
# 3      4_F_cp.jpg    4_F_lm.jpg  ...    4_F_mp.jpg    4_F_ip.jpg
# 4      5_F_cp.jpg    5_F_lm.jpg  ...    5_F_mp.jpg    5_F_ip.jpg
# ..            ...           ...  ...           ...           ...
# 660  661_M_cp.jpg  661_M_lm.jpg  ...  661_M_mp.jpg  661_M_ip.jpg
# 661  662_M_cp.jpg  662_M_lm.jpg  ...  662_M_mp.jpg  662_M_ip.jpg
# 662  663_M_cp.jpg  663_M_lm.jpg  ...  663_M_mp.jpg  663_M_ip.jpg
# 663  664_M_cp.jpg  664_M_lm.jpg  ...  664_M_mp.jpg  664_M_ip.jpg
# 664  665_M_cp.jpg  665_M_lm.jpg  ...  665_M_mp.jpg  665_M_ip.jpg
#
# [1236 rows x 7 columns]

# %%
x = x.reset_index(drop=True)
x
# Out:
#             carpal          lmcp  ...          mpip            ip
# 0       1_F_cp.jpg    1_F_lm.jpg  ...    1_F_mp.jpg    1_F_ip.jpg
# 1       2_F_cp.jpg    2_F_lm.jpg  ...    2_F_mp.jpg    2_F_ip.jpg
# 2       3_F_cp.jpg    3_F_lm.jpg  ...    3_F_mp.jpg    3_F_ip.jpg
# 3       4_F_cp.jpg    4_F_lm.jpg  ...    4_F_mp.jpg    4_F_ip.jpg
# 4       5_F_cp.jpg    5_F_lm.jpg  ...    5_F_mp.jpg    5_F_ip.jpg
# ...            ...           ...  ...           ...           ...
# 1231  661_M_cp.jpg  661_M_lm.jpg  ...  661_M_mp.jpg  661_M_ip.jpg
# 1232  662_M_cp.jpg  662_M_lm.jpg  ...  662_M_mp.jpg  662_M_ip.jpg
# 1233  663_M_cp.jpg  663_M_lm.jpg  ...  663_M_mp.jpg  663_M_ip.jpg
# 1234  664_M_cp.jpg  664_M_lm.jpg  ...  664_M_mp.jpg  664_M_ip.jpg
# 1235  665_M_cp.jpg  665_M_lm.jpg  ...  665_M_mp.jpg  665_M_ip.jpg
#
# [1236 rows x 7 columns]

# %%
x.to_csv('/content/drive/MyDrive/2차 프로젝트 원본 데이터/Yolo_df.csv',index=False)

# %%
test = pd.read_csv('/content/drive/MyDrive/2차 프로젝트 원본 데이터/Yolo_df.csv')
test
# Out:
#             carpal          lmcp  ...          mpip            ip
# 0       1_F_cp.jpg    1_F_lm.jpg  ...    1_F_mp.jpg    1_F_ip.jpg
# 1       2_F_cp.jpg    2_F_lm.jpg  ...    2_F_mp.jpg    2_F_ip.jpg
# 2       3_F_cp.jpg    3_F_lm.jpg  ...    3_F_mp.jpg    3_F_ip.jpg
# 3       4_F_cp.jpg    4_F_lm.jpg  ...    4_F_mp.jpg    4_F_ip.jpg
# 4       5_F_cp.jpg    5_F_lm.jpg  ...    5_F_mp.jpg    5_F_ip.jpg
# ...            ...           ...  ...           ...           ...
# 1231  661_M_cp.jpg  661_M_lm.jpg  ...  661_M_mp.jpg  661_M_ip.jpg
# 1232  662_M_cp.jpg  662_M_lm.jpg  ...  662_M_mp.jpg  662_M_ip.jpg
# 1233  663_M_cp.jpg  663_M_lm.jpg  ...  663_M_mp.jpg  663_M_ip.jpg
# 1234  664_M_cp.jpg  664_M_lm.jpg  ...  664_M_mp.jpg  664_M_ip.jpg
# 1235  665_M_cp.jpg  665_M_lm.jpg  ...  665_M_mp.jpg  665_M_ip.jpg
#
# [1236 rows x 7 columns]
